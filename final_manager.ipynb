# %%
from file_manager_func import *

# %%
while True:
    command = str(input(f"Введите команду из списка:\n{command_list} "))
    action = command

    if action == "create_folder":
        create_folder()
    elif action == "delete_folder":
        delete_folder()
    elif action == "move_to_folder":
        move_to_folder()
    elif action == "create_file":
        create_file()
    elif action == "write_to_file":
        write_to_file()
    elif action == "read_file":
        read_file()
    elif action == "delete_file":
        delete_file()
    elif action == "copy_file":
        copy_file()
    elif action == "move_file":
        move_file()
    elif action == "rename_file":
        rename_file()
    elif action == "exit":
        print('Работа файлового менеджера завершена')
        break
    else:
        print("Неизвестная команда. Попробуйте ещё раз")
# Out:
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  move_file
# Путь начальной директории: C:\\alisa\\work_direct\\folder1\\a2.txt
# Путь конечной директории: C:\\alisa\\work_direct
# Файл 'C:\\alisa\\work_direct\\folder1\\a2.txt' перемещен в 'C:\\alisa\\work_direct'.
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  move_to_folder
# Вы находитесь в данной директории:  C:\alisa\work_direct
# Название папки для прехода: folder1
# Перемещение в папку 'folder1' произошло успешно.
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  create_file
# Название файла для создания: a3.txt
# Файл "a3.txt" успешно создан
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  copy_file
# Путь файла: C:\\alisa\\work_direct\\folder1\\a3.txt
# Путь скопированного файла: C:\\alisa\\work_direct
# Файл 'C:\\alisa\\work_direct\\folder1\\a3.txt' скопирован в 'C:\\alisa\\work_direct'.
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  move_file
# Путь начальной директории: C:\\alisa\\work_direct\\a3.txt
# Путь конечной директории: C:\\alisa\\work_direct\\folder3
# Файл 'C:\\alisa\\work_direct\\a3.txt' перемещен в 'C:\\alisa\\work_direct\\folder3'.
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  rename_file
# Вы находитесь в данной директории:  C:\alisa\work_direct\folder1
# Укажите путь старого файла: C:\\alisa\\work_direct\\folder3\\a3.txt
# Укажите новое название файла: newa3.txt
# Файл  успешно переименован на 'newa3.txt'.
# Введите команду из списка:
# Создание папку - create_folder
# Удаление папки - delete_folder
# Перемещение в папку - move_to_folder
# Создание файл - create_file
# Запись в файл - write_to_file
# Просмотр содержимого файла - read_file
# Удаление файла - delete_file
# Копирование файла - copy_file
# Перемещение файла - move_file
# Переименование файла - rename_file
# Выход - exit
#  exit
# Работа файлового менеджера завершена

# %%
C:\\alisa\\work_direct\\a1
